# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.window import Window
import pyspark.sql.types as T

# %%
app_name='PruebaBBVA'

# %%
spark = SparkSession.builder\
        .master("local[*]")\
        .config("spark.sql.execution.arrow.pyspark.enabled", "true")\
        .appName(app_name)\
        .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/02 13:07:58 WARN Utils: Your hostname, MacBook-Pro-de-Alberto.local, resolves to a loopback address: 127.0.0.1; using 192.168.3.140 instead (on interface en0)
# 26/03/02 13:07:58 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/02 13:07:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
schema = T.StructType([
    T.StructField("sensor_id", T.IntegerType(), False),
    T.StructField("timestamp", T.TimestampType(), False),
    T.StructField("voltaje", T.DoubleType(), True),
    T.StructField("corriente", T.DoubleType(), True),
    T.StructField("status", T.StringType(), True)
])
# Lectura perezosa (Lazy Load)
#df_raw = spark.read.csv("data_sensores.csv", header=True, schema=schema)

# %%
df = spark.createDataFrame(data, columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = spark.createDataFrame(data, columns)
#
# NameError: name 'data' is not defined

# %%
#Ejemplo de operaciones optimizadas con pandas UDF
"""
import pandas as pd
from pyspark.sql.functions import pandas_udf
from pyspark.sql.types import DoubleType

@pandas_udf(DoubleType())
def mi_funcion_matematica(v: pd.Series) -> pd.Series:
    import numpy as np
    return np.sin(v) + np.exp(np.power(v, 2)) #Se puede usar numpy para hacer de todas las operaciones, operaciones vectorizadas

# Aplicación en el DataFrame de Spark
df_con_calculo = df.withColumn("resultado", mi_funcion_matematica(df["mi_columna"]))
"""
# Out:
# '\nimport pandas as pd\nfrom pyspark.sql.functions import pandas_udf\nfrom pyspark.sql.types import DoubleType\n\n@pandas_udf(DoubleType())\ndef mi_funcion_matematica(v: pd.Series) -> pd.Series:\n    import numpy as np\n    return np.sin(v) + np.exp(np.power(v, 2)) #Se puede usar numpy para hacer de todas las operaciones, operaciones vectorizadas\n\n# Aplicación en el DataFrame de Spark\ndf_con_calculo = df.withColumn("resultado", mi_funcion_matematica(df["mi_columna"]))\n'
